# %%
import joblib

# %%
model = joblib.load('./models/rf.pkl')

# %%
model.steps
# Out:
# [('preprocess',
#   ColumnTransformer(remainder='passthrough',
#                     transformers=[('scale', StandardScaler(),
#                                    Index(['age', 'flight_distance', 'inflight_wifi_service',
#          'departure_arrival_time_convenient', 'ease_of_online_booking',
#          'gate_location', 'food_and_drink', 'online_boarding', 'seat_comfort',
#          'inflight_entertainment', 'on_board_service', 'leg_room_service',
#          'baggage_handling', 'checkin_service', 'inflight_service',
#          'cleanliness', 'departure_delay_in_minutes', 'arrival_delay_in_minutes',
#          'arrival_delayed_missing', 'age_group_codes',
#          'departure_delay_group_codes', 'arrival_delay_group_codes',
#          'class_codes'],
#         dtype='object')),
#                                   ('one', OneHotEncoder(),
#                                    Index(['gender', 'customer_type', 'type_of_travel'], dtype='object'))])),
# ...
